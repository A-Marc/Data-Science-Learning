# %%
import requests

# %%
for i in range(1,50):
    a=requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open(f"htmls/pages{i}.html","w" , encoding="utf-8")as f:
        f.write(a.text)
        print(f"page downloaded {i}")
